# %%
client_id = "676ebf79e44d4f658b0a7b825a5bb76e"
client_secret = "6cb0e5a3f6d7470eb4aaccf5ea46a3dc"
redirect_uri = "http://localhost:9000"

# %%
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\users\michael\anaconda3\envs\mytfenv\lib\site-packages (2.22.1)
# Requirement already satisfied: six>=1.15.0 in c:\users\michael\anaconda3\envs\mytfenv\lib\site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: redis>=3.5.3 in c:\users\michael\anaconda3\envs\mytfenv\lib\site-packages (from spotipy) (4.5.1)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\michael\anaconda3\envs\mytfenv\lib\site-packages (from spotipy) (1.26.7)
# Requirement already satisfied: requests>=2.25.0 in c:\users\michael\anaconda3\envs\mytfenv\lib\site-packages (from spotipy) (2.26.0)
# Requirement already satisfied: async-timeout>=4.0.2 in c:\users\michael\anaconda3\envs\mytfenv\lib\site-packages (from redis>=3.5.3->spotipy) (4.0.2)
# Requirement already satisfied: importlib-metadata>=1.0 in c:\users\michael\anaconda3\envs\mytfenv\lib\site-packages (from redis>=3.5.3->spotipy) (4.8.1)
# Requirement already satisfied: typing-extensions in c:\users\michael\anaconda3\envs\mytfenv\lib\site-packages (from redis>=3.5.3->spotipy) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\michael\anaconda3\envs\mytfenv\lib\site-packages (from importlib-metadata>=1.0->redis>=3.5.3->spotipy) (3.5.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\michael\anaconda3\envs\mytfenv\lib\site-packages (from requests>=2.25.0->spotipy) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\michael\anaconda3\envs\mytfenv\lib\site-packages (from requests>=2.25.0->spotipy) (2021.5.30)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\michael\anaconda3\envs\mytfenv\lib\site-packages (from requests>=2.25.0->spotipy) (2.0.6)

# %%
import spotipy

# %%
from spotipy.oauth2 import SpotifyOAuth

# %%
# Connect with API Keys created earlier
scope = "user-read-recently-played"
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(scope=scope,
                                               client_id=client_id,
                                              client_secret=client_secret,
                                              redirect_uri=redirect_uri))

# %%
results = sp.current_user_recently_played()

# %%
type(results)
# Out:
# dict

# %%
results.keys()
# Out:
# dict_keys(['items', 'next', 'cursors', 'limit', 'href'])

# %%
for idx, item in enumerate(results['items']):
    track_id = item['track']
    track_name = track_id['name']
    artist_name = track_id['artists'][0]['name']
    
    print(f"{idx}.) {track_name} by {artist_name}")
# Out:
# 0.) Tired by Su Lee
# 1.) Pictures of Girls by Wallows
# 2.) t-shirt by boy pablo
# 3.) It's Only Right by Wallows
# 4.) Everybody Wants To Rule The World by Tears For Fears
# 5.) Saw You In A Dream by The Japanese House
# 6.) Humming by Turnover
# 7.) Die For You by Joji
# 8.) Epitaph by Hippo Campus
# 9.) Good Riddance (Time of Your Life) by Green Day
# 10.) At My Worst by Pink Sweat$
# 11.) Can I Call You Tonight? by Dayglow
# 12.) SLOW DANCING IN THE DARK by Joji
# 13.) On Melancholy Hill by Gorillaz
# 14.) Ground by Wallows
# 15.) Glimpse of Us by Joji
# 16.) Honestly by Hippo Campus
# 17.) Anxious by Hippo Campus
# 18.) you won't be there for me by slchld
# 19.) Just Like A Movie by Wallows
# 20.) Dizzy On the Comedown by Turnover
# 21.) Super Natural by Turnover
# 22.) intro to a movie about a f*cking loser by azar & SEDVTED
# 23.) Sunshine Type by Turnover
# 24.) Mr. Brightside by The Killers
# 25.) So Long Goodbye by Sum 41
# 26.) Upside Down by The Story So Far
# 27.) Malibu 1992 by COIN
# 28.) Black Licorice by Peach Pit
# 29.) Drunk on Halloween by Wallows
# 30.) Butterfly Dream by Turnover
# 31.) Only Friend by Wallows
# 32.) Line by The Story So Far
# 33.) Bambi by Hippo Campus
# 34.) Narcissist (feat. The 1975) by No Rome
# 35.) Iris by The Goo Goo Dolls
# 36.) Clairvoyant by The Story So Far
# 37.) Slow Dances by Winnetka Bowling League
# 38.) tkm by boy pablo
# 39.) Doubt by Hippo Campus
# 40.) Golden by Hippo Campus
# 41.) Name by The Goo Goo Dolls
# 42.) Take Me as You Please by The Story So Far
# 43.) Simply by ADOY
# 44.) Younger by The Hails
# 45.) Nice to See You by Vansire
# 46.) These Days by Wallows
# 47.) Little Lion Man by Mumford & Sons
# 48.) Ride or Die by Hippo Campus
# 49.) Pure Devotion by Turnover

# %%
hippo_campus = sp.artist("1btWGBz4Uu1HozTwb2Lm8A")

# %%
hippo_campus
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/1btWGBz4Uu1HozTwb2Lm8A'},
#  'followers': {'href': None, 'total': 578603},
#  'genres': ['indie pop',
#   'indie poptimism',
#   'indie rock',
#   'minneapolis indie',
#   'modern alternative rock',
#   'modern rock'],
#  'href': 'https://api.spotify.com/v1/artists/1btWGBz4Uu1HozTwb2Lm8A',
#  'id': '1btWGBz4Uu1HozTwb2Lm8A',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eba6083ccfc09ae97298e8201d',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab67616100005174a6083ccfc09ae97298e8201d',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f178a6083ccfc09ae97298e8201d',
#    'width': 160}],
#  'name': 'Hippo Campus',
#  'popularity': 64,
#  'type': 'artist',
#  'uri': 'spotify:artist:1btWGBz4Uu1HozTwb2Lm8A'}

# %%
hippo_albums = sp.artist_albums(hippo_campus['id'],limit=50)

# %%
for album in hippo_albums['items']:
    print(f"Album: {album['name']} -- ID: {album['id']}")
# Out:
# Album: LP3 -- ID: 08I3iemI4Gfn7kp4wm9FmX
# Album: Demos II -- ID: 4xLfXadj5rWOww2Na6LiBd
# Album: Demos I -- ID: 42kxHrj7K9MyYm6Dz5Px7N
# Album: Bambi -- ID: 6tGEWfRhonWuuQikgOnYhN
# Album: Landmark -- ID: 0vb1g018puu47StlIi9wxC
# Album: Ashtray (Sachi of Joy Again Remix) -- ID: 6H6A3ZS7EEPN5IClASA4rH
# Album: Bang Bang -- ID: 4ZFKLXH2lTaQn5GxVH6zYg
# Album: Ride or Die -- ID: 1vMfrkDvP3CDkYGt19voDl
# Album: Semi Pro -- ID: 52lZvD8hEnCoYnnvVC6dbp
# Album: Boys -- ID: 6GekJIWdpmASWvY6maRfHH
# Album: Good Dog, Bad Dream -- ID: 1E5WY8NbdOkxJr05k5Ld4R
# Album: Sex Tape -- ID: 2HOh6Vrm6LO8BPazURNiSc
# Album: Bad Dream Baby -- ID: 1TBnwPS0Mbn5DsRNeSlvrR
# Album: Spotify Singles -- ID: 1ghdZvVVCMbTkf6BDsEg78
# Album: Golden -- ID: 4bv9cX6lFo3M3NG8MGkQL6
# Album: Bambi -- ID: 42v1CWuIolBwAY1dX5crKi
# Album: Passenger -- ID: 3DvpSUjb7mVHkm3boc5yGB
# Album: warm glow -- ID: 4Haa4Xjv1O6cjPY2CwmbY8
# Album: Way It Goes -- ID: 3qAZgaJAHQippvuZnjyRAF
# Album: Last Snowstorm of the Year -- ID: 7sLjMo10hZ2W0rR8WbloQX
# Album: Monsoon -- ID: 2IrmvhTi77fVdBUeRLYH0L
# Album: Boyish -- ID: 2leVTejjDLcx1ZvnPogJeb
# Album: South -- ID: 1TW8DEoKubumkQIbsaNF3h
# Album: Alive In Chicago -- ID: 6fYFRVJo4XoCiDmSAH8Uym
# Album: The Halocline - Single -- ID: 1qiJgYe8I90EYW2pJ05wL7
# Album: South - Single -- ID: 7CB7VmCQS0P2HOvfYHGEiA
# Album: Little Grace -- ID: 2rmRTeBEPlluwNfaaZpfHO
# Album: Bashful Creatures -- ID: 2O8JV6cLUmyO3w2nf5PuBh
# Album: Festival -- ID: 2dVys2WKYOxwwF3id45pl5

# %%
album_names = []
albums = []

for album in hippo_albums['items']:
    album_name = album['name']
    album_id = album['id']
    # Very ugly hacky code to clean out the duplicates, but it works
    if album_name[:3] not in album_names and "remix" not in album_name and "Karaoke" not in album_name and "Live" not in album_name:
        album_names.append(album_name[:3] )
        albums.append((album_name,album_id))

# %%
albums
# Out:
# [('LP3', '08I3iemI4Gfn7kp4wm9FmX'),
#  ('Demos II', '4xLfXadj5rWOww2Na6LiBd'),
#  ('Bambi', '6tGEWfRhonWuuQikgOnYhN'),
#  ('Landmark', '0vb1g018puu47StlIi9wxC'),
#  ('Ashtray (Sachi of Joy Again Remix)', '6H6A3ZS7EEPN5IClASA4rH'),
#  ('Bang Bang', '4ZFKLXH2lTaQn5GxVH6zYg'),
#  ('Ride or Die', '1vMfrkDvP3CDkYGt19voDl'),
#  ('Semi Pro', '52lZvD8hEnCoYnnvVC6dbp'),
#  ('Boys', '6GekJIWdpmASWvY6maRfHH'),
#  ('Good Dog, Bad Dream', '1E5WY8NbdOkxJr05k5Ld4R'),
#  ('Sex Tape', '2HOh6Vrm6LO8BPazURNiSc'),
#  ('Bad Dream Baby', '1TBnwPS0Mbn5DsRNeSlvrR'),
#  ('Spotify Singles', '1ghdZvVVCMbTkf6BDsEg78'),
#  ('Golden', '4bv9cX6lFo3M3NG8MGkQL6'),
#  ('Passenger', '3DvpSUjb7mVHkm3boc5yGB'),
#  ('warm glow', '4Haa4Xjv1O6cjPY2CwmbY8'),
#  ('Way It Goes', '3qAZgaJAHQippvuZnjyRAF'),
#  ('Last Snowstorm of the Year', '7sLjMo10hZ2W0rR8WbloQX'),
#  ('Monsoon', '2IrmvhTi77fVdBUeRLYH0L'),
#  ('South', '1TW8DEoKubumkQIbsaNF3h'),
#  ('Alive In Chicago', '6fYFRVJo4XoCiDmSAH8Uym'),
#  ('The Halocline - Single', '1qiJgYe8I90EYW2pJ05wL7'),
#  ('Little Grace', '2rmRTeBEPlluwNfaaZpfHO'),
#  ('Bashful Creatures', '2O8JV6cLUmyO3w2nf5PuBh'),
#  ('Festival', '2dVys2WKYOxwwF3id45pl5')]

# %%
final_album_list = albums[:-5]

# %%
final_album_list
# Out:
# [('LP3', '08I3iemI4Gfn7kp4wm9FmX'),
#  ('Demos II', '4xLfXadj5rWOww2Na6LiBd'),
#  ('Bambi', '6tGEWfRhonWuuQikgOnYhN'),
#  ('Landmark', '0vb1g018puu47StlIi9wxC'),
#  ('Ashtray (Sachi of Joy Again Remix)', '6H6A3ZS7EEPN5IClASA4rH'),
#  ('Bang Bang', '4ZFKLXH2lTaQn5GxVH6zYg'),
#  ('Ride or Die', '1vMfrkDvP3CDkYGt19voDl'),
#  ('Semi Pro', '52lZvD8hEnCoYnnvVC6dbp'),
#  ('Boys', '6GekJIWdpmASWvY6maRfHH'),
#  ('Good Dog, Bad Dream', '1E5WY8NbdOkxJr05k5Ld4R'),
#  ('Sex Tape', '2HOh6Vrm6LO8BPazURNiSc'),
#  ('Bad Dream Baby', '1TBnwPS0Mbn5DsRNeSlvrR'),
#  ('Spotify Singles', '1ghdZvVVCMbTkf6BDsEg78'),
#  ('Golden', '4bv9cX6lFo3M3NG8MGkQL6'),
#  ('Passenger', '3DvpSUjb7mVHkm3boc5yGB'),
#  ('warm glow', '4Haa4Xjv1O6cjPY2CwmbY8'),
#  ('Way It Goes', '3qAZgaJAHQippvuZnjyRAF'),
#  ('Last Snowstorm of the Year', '7sLjMo10hZ2W0rR8WbloQX'),
#  ('Monsoon', '2IrmvhTi77fVdBUeRLYH0L'),
#  ('South', '1TW8DEoKubumkQIbsaNF3h')]

# %%
hippo_song_ids = []

for album_name, album_id in final_album_list:
    tracks = sp.album_tracks(album_id)['items']
    for track in tracks:
        track_name = track['name']
        track_id = track['id']
        hippo_song_ids.append((album_name, album_id, track_name, track_id))

# %%
hippo_song_ids[0]
# Out:
# ('LP3', '08I3iemI4Gfn7kp4wm9FmX', '2 Young 2 Die', '3OrarbuyYqIoYUsPRApBK3')

# %%
len(hippo_song_ids)
# Out:
# 75

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
features = sp.audio_features(tracks=['3OrarbuyYqIoYUsPRApBK3'])

# %%
features
# Out:
# [{'danceability': 0.501,
#   'energy': 0.66,
#   'key': 7,
#   'loudness': -8.099,
#   'mode': 1,
#   'speechiness': 0.079,
#   'acousticness': 0.26,
#   'instrumentalness': 0.00106,
#   'liveness': 0.141,
#   'valence': 0.298,
#   'tempo': 110.112,
#   'type': 'audio_features',
#   'id': '3OrarbuyYqIoYUsPRApBK3',
#   'uri': 'spotify:track:3OrarbuyYqIoYUsPRApBK3',
#   'track_href': 'https://api.spotify.com/v1/tracks/3OrarbuyYqIoYUsPRApBK3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3OrarbuyYqIoYUsPRApBK3',
#   'duration_ms': 220516,
#   'time_signature': 4}]

# %%
pd.Series(features[0])
# Out:
# danceability                                                    0.501
# energy                                                           0.66
# key                                                                 7
# loudness                                                       -8.099
# mode                                                                1
# speechiness                                                     0.079
# acousticness                                                     0.26
# instrumentalness                                              0.00106
# liveness                                                        0.141
# valence                                                         0.298
# tempo                                                         110.112
# type                                                   audio_features
# id                                             3OrarbuyYqIoYUsPRApBK3
# uri                              spotify:track:3OrarbuyYqIoYUsPRApBK3
# track_href          https://api.spotify.com/v1/tracks/3OrarbuyYqIo...
# analysis_url        https://api.spotify.com/v1/audio-analysis/3Ora...
# duration_ms                                                    220516
# time_signature                                                      4
# dtype: object

# %%
df = pd.DataFrame()

# This will take awhile, due to us not using the batch feature
for album_name,album_id,track_name, track_id in hippo_song_ids:
    features = sp.audio_features(tracks=[track_id])[0]
    features['album_name'] = album_name
    features['album_id'] = album_id
    features['track_name'] = track_name
    ser = pd.Series(features)
    df = pd.concat([df,ser],axis=1)
# Out:
# c:\users\michael\anaconda3\envs\mytfenv\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   # Remove the CWD from sys.path while we load stuff.

# %%
df = df.transpose().set_index('id')
df.head()[['danceability', 'energy', 'key', 'acousticness','album_name','track_name']]
# Out:
#                        danceability energy key acousticness album_name  \
# id
# 3OrarbuyYqIoYUsPRApBK3        0.501   0.66   7         0.26        LP3
# 2t1yDVrhGCOkyrAKbXBOi4        0.662  0.756   9      0.00688        LP3
# 5khfbDDp5u3RtOem4m3are        0.509  0.942   6     0.000677        LP3
# 2RPInGYh3BMVWm6buPzMdq        0.605  0.769   6        0.199        LP3
# 5pi2q0UhOISnpkscERtxIa        0.556  0.817   4        0.219        LP3
#
#                            track_name
# id
# 3OrarbuyYqIoYUsPRApBK3  2 Young 2 Die
# 2t1yDVrhGCOkyrAKbXBOi4       Blew Its
# 5khfbDDp5u3RtOem4m3are        Ashtray
# 2RPInGYh3BMVWm6buPzMdq      Bang Bang
# 5pi2q0UhOISnpkscERtxIa       Semi Pro

# %%
df.columns
# Out:
# Index(['acousticness', 'album_id', 'album_name', 'analysis_url',
#        'danceability', 'duration_ms', 'energy', 'instrumentalness', 'key',
#        'liveness', 'loudness', 'mode', 'speechiness', 'tempo',
#        'time_signature', 'track_href', 'track_name', 'type', 'uri', 'valence'],
#       dtype='object')

# %%
data_features = df.drop(['type', 'uri', 'track_href', 'analysis_url','album_name', 'album_id', 'track_name'],axis=1)

# %%
data_features.describe()[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness','acousticness']]
# Out:
#         danceability  energy  key  loudness  mode  speechiness  acousticness
# count         75.000  75.000   75    75.000    75      75.0000       75.0000
# unique        57.000  58.000   12    60.000     2      58.0000       57.0000
# top            0.515   0.771    9    -5.081     1       0.0394        0.0339
# freq           5.000   5.000   15     5.000    68       5.0000        6.0000

# %%
for col in data_features.columns:
    data_features[col] = data_features[col].apply(float)

# %%
data_features.describe()[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness','acousticness']]
# Out:
#        danceability     energy        key   loudness       mode  speechiness  \
# count     75.000000  75.000000  75.000000  75.000000  75.000000    75.000000
# mean       0.514129   0.683107   5.333333  -6.513520   0.906667     0.059375
# std        0.128160   0.190755   3.553960   2.612998   0.292858     0.047516
# min        0.087700   0.222000   0.000000 -14.838000   0.000000     0.023700
# 25%        0.461000   0.543500   2.000000  -8.089000   1.000000     0.038300
# 50%        0.542000   0.717000   5.000000  -6.182000   1.000000     0.045200
# 75%        0.600000   0.815000   9.000000  -4.903000   1.000000     0.059950
# max        0.739000   0.974000  11.000000  -1.426000   1.000000     0.368000
#
#        acousticness
# count     75.000000
# mean       0.299375
# std        0.276505
# min        0.000331
# 25%        0.036550
# 50%        0.216000
# 75%        0.495000
# max        0.938000

# %%
plt.figure(dpi=200)
sns.scatterplot(x='loudness',y='acousticness',data=data_features,hue=df['album_name'])
plt.legend(loc=(1.05,0.2))

# %%
import scipy

# %%
distances = scipy.spatial.distance.cdist(data_features, data_features, metric='euclidean')

# %%
distances.shape
# Out:
# (75, 75)

# %%
plt.figure(dpi=200)
sns.heatmap(distances)

# %%
df[distances==distances.max()][['album_name','track_name']]
# Out:
#                        album_name     track_name
# id
# 18btLbmzZFaBKPohbp9svn   Landmark      Interlude
# 4TqKdg1tnqNw4iTw9GUzDm      South  The Halocline

# %%
no_time = data_features.drop(['duration_ms','time_signature'],axis=1)

# %%
distances = scipy.spatial.distance.cdist(no_time, no_time, metric='euclidean')

# %%
distances.max()
# Out:
# 120.26068057312

# %%
df[distances==distances.max()][['album_name','track_name']]
# Out:
#                        album_name     track_name
# id
# 1OrhwZaLMoymvyxSgKNBLk      Bambi       Mistakes
# 0lgktkQ3wjpnyxzrHgdSr1      Bambi  Think It Over
